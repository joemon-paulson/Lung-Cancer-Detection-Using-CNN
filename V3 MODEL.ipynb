# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"D:\M.sc BDA\Projects\Lung Cancer Detection using CNN\Data\train")
val_path = (r"D:\M.sc BDA\Projects\Lung Cancer Detection using CNN\Data\valid")
test_path = (r"D:\M.sc BDA\Projects\Lung Cancer Detection using CNN\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

base_model = InceptionV3(input_shape = (350, 350, 3), 
                         include_top = False, 
                         weights = 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 8s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Add a final sigmoid layer with 4 node for classification output
x = layers.Dense(4, activation='sigmoid')(x)

model_incep = tf.keras.models.Model(base_model.input, x)

model_incep.compile(optimizer = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001), 
                    loss = 'categorical_crossentropy', 
                    metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_incep_best_model.hdf5",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
incep = model_incep.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 8.4416 - accuracy: 0.4441
# Epoch 1: val_accuracy improved from -inf to 0.54286, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 361s 3s/step - loss: 8.4416 - accuracy: 0.4441 - val_loss: 4.2937 - val_accuracy: 0.5429
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 2.9089 - accuracy: 0.5559
# Epoch 2: val_accuracy did not improve from 0.54286
# 122/122 [==============================] - 324s 3s/step - loss: 2.9089 - accuracy: 0.5559 - val_loss: 3.2069 - val_accuracy: 0.5000
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.7635 - accuracy: 0.5970
# Epoch 3: val_accuracy did not improve from 0.54286
# 122/122 [==============================] - 325s 3s/step - loss: 1.7635 - accuracy: 0.5970 - val_loss: 1.7567 - val_accuracy: 0.5429
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2550 - accuracy: 0.6102
# Epoch 4: val_accuracy improved from 0.54286 to 0.57143, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 328s 3s/step - loss: 1.2550 - accuracy: 0.6102 - val_loss: 1.4019 - val_accuracy: 0.5714
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9989 - accuracy: 0.6464
# Epoch 5: val_accuracy improved from 0.57143 to 0.75714, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 354s 3s/step - loss: 0.9989 - accuracy: 0.6464 - val_loss: 0.5401 - val_accuracy: 0.7571
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9661 - accuracy: 0.6727
# Epoch 6: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 338s 3s/step - loss: 0.9661 - accuracy: 0.6727 - val_loss: 1.0902 - val_accuracy: 0.6429
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8650 - accuracy: 0.6974
# Epoch 7: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 323s 3s/step - loss: 0.8650 - accuracy: 0.6974 - val_loss: 0.9441 - val_accuracy: 0.6286
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7623 - accuracy: 0.7434
# Epoch 8: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 349s 3s/step - loss: 0.7623 - accuracy: 0.7434 - val_loss: 0.7374 - val_accuracy: 0.7286
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7585 - accuracy: 0.7484
# Epoch 9: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 411s 3s/step - loss: 0.7585 - accuracy: 0.7484 - val_loss: 0.9656 - val_accuracy: 0.6000
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7564 - accuracy: 0.7401
# Epoch 10: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 463s 4s/step - loss: 0.7564 - accuracy: 0.7401 - val_loss: 0.5239 - val_accuracy: 0.7571
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.7418
# Epoch 11: val_accuracy did not improve from 0.75714
# 122/122 [==============================] - 331s 3s/step - loss: 0.6897 - accuracy: 0.7418 - val_loss: 0.9408 - val_accuracy: 0.6714
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5749 - accuracy: 0.8092
# Epoch 12: val_accuracy improved from 0.75714 to 0.80000, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 336s 3s/step - loss: 0.5749 - accuracy: 0.8092 - val_loss: 0.6842 - val_accuracy: 0.8000
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5777 - accuracy: 0.7845
# Epoch 13: val_accuracy did not improve from 0.80000
# 122/122 [==============================] - 354s 3s/step - loss: 0.5777 - accuracy: 0.7845 - val_loss: 0.5717 - val_accuracy: 0.7429
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.7747
# Epoch 14: val_accuracy did not improve from 0.80000
# 122/122 [==============================] - 270s 2s/step - loss: 0.5863 - accuracy: 0.7747 - val_loss: 0.7965 - val_accuracy: 0.6571
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5033 - accuracy: 0.8372
# Epoch 15: val_accuracy did not improve from 0.80000
# 122/122 [==============================] - 278s 2s/step - loss: 0.5033 - accuracy: 0.8372 - val_loss: 0.7932 - val_accuracy: 0.6714
# Epoch 16/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6102 - accuracy: 0.7993
# Epoch 16: val_accuracy improved from 0.80000 to 0.81429, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 255s 2s/step - loss: 0.6102 - accuracy: 0.7993 - val_loss: 0.4440 - val_accuracy: 0.8143
# Epoch 17/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.8158
# Epoch 17: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 292s 2s/step - loss: 0.5219 - accuracy: 0.8158 - val_loss: 0.5247 - val_accuracy: 0.7857
# Epoch 18/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.8339
# Epoch 18: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 246s 2s/step - loss: 0.4757 - accuracy: 0.8339 - val_loss: 0.6067 - val_accuracy: 0.7571
# Epoch 19/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4748 - accuracy: 0.8207
# Epoch 19: val_accuracy improved from 0.81429 to 0.84286, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 248s 2s/step - loss: 0.4748 - accuracy: 0.8207 - val_loss: 0.3978 - val_accuracy: 0.8429
# Epoch 20/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.8141
# Epoch 20: val_accuracy improved from 0.84286 to 0.85714, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 253s 2s/step - loss: 0.4805 - accuracy: 0.8141 - val_loss: 0.3700 - val_accuracy: 0.8571
# Epoch 21/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4345 - accuracy: 0.8257
# Epoch 21: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 260s 2s/step - loss: 0.4345 - accuracy: 0.8257 - val_loss: 0.4070 - val_accuracy: 0.8286
# Epoch 22/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3780 - accuracy: 0.8569
# Epoch 22: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 248s 2s/step - loss: 0.3780 - accuracy: 0.8569 - val_loss: 0.4619 - val_accuracy: 0.8286
# Epoch 23/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8438
# Epoch 23: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 241s 2s/step - loss: 0.4212 - accuracy: 0.8438 - val_loss: 0.3889 - val_accuracy: 0.8429
# Epoch 24/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3960 - accuracy: 0.8701
# Epoch 24: val_accuracy improved from 0.85714 to 0.90000, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 244s 2s/step - loss: 0.3960 - accuracy: 0.8701 - val_loss: 0.2281 - val_accuracy: 0.9000
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.8734
# Epoch 25: val_accuracy did not improve from 0.90000
# 122/122 [==============================] - 241s 2s/step - loss: 0.3487 - accuracy: 0.8734 - val_loss: 0.5295 - val_accuracy: 0.7857
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8832
# Epoch 26: val_accuracy did not improve from 0.90000
# 122/122 [==============================] - 240s 2s/step - loss: 0.3252 - accuracy: 0.8832 - val_loss: 0.2784 - val_accuracy: 0.9000
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8849
# Epoch 27: val_accuracy did not improve from 0.90000
# 122/122 [==============================] - 240s 2s/step - loss: 0.3183 - accuracy: 0.8849 - val_loss: 0.3383 - val_accuracy: 0.8714
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.8668
# Epoch 28: val_accuracy did not improve from 0.90000
# 122/122 [==============================] - 239s 2s/step - loss: 0.3606 - accuracy: 0.8668 - val_loss: 0.4316 - val_accuracy: 0.8286
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.8717
# Epoch 29: val_accuracy improved from 0.90000 to 0.91429, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 242s 2s/step - loss: 0.4048 - accuracy: 0.8717 - val_loss: 0.2973 - val_accuracy: 0.9143
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.8832
# Epoch 30: val_accuracy did not improve from 0.91429
# 122/122 [==============================] - 239s 2s/step - loss: 0.3467 - accuracy: 0.8832 - val_loss: 0.3957 - val_accuracy: 0.8571
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8980
# Epoch 31: val_accuracy did not improve from 0.91429
# 122/122 [==============================] - 241s 2s/step - loss: 0.3419 - accuracy: 0.8980 - val_loss: 0.5820 - val_accuracy: 0.8000
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9013
# Epoch 32: val_accuracy did not improve from 0.91429
# 122/122 [==============================] - 242s 2s/step - loss: 0.2661 - accuracy: 0.9013 - val_loss: 0.4846 - val_accuracy: 0.8286

# %%
# Loading the Best Fit Model 
model = load_model("./ct_incep_best_model.hdf5")

# %%
# Checking the Accuracy of the Model 
accuracy_incep = model.evaluate_generator(generator= test_data)[1] 
print(f"The accuracy of the model is = {accuracy_incep*100} %")
# Out:
# The accuracy of the model is = 80.95238208770752 %

# %%
incep.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Plot model performance
acc = incep.history['accuracy']
val_acc = incep.history['val_accuracy']
loss = incep.history['loss']
val_loss = incep.history['val_loss']
epochs_range = range(1, len(incep.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()
